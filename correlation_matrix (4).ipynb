# %%
from scipy.stats import norm
import numpy as np
import yfinance as yf
import pandas as pd
from ta.volatility import AverageTrueRange
from datetime import datetime
from datetime import date
#start='2010-01-01'
end=date.today()
def get_historical_data(stk):

    df = yf.download(stk,periods='max', interval="1wk").dropna()
    #df['year']=df.index.isocalendar().year.astype(int)
    return df

stocks=['HYG','IEF','LQD','UUP','TLT','MSOS']
arr=[]
daf=pd.DataFrame()
a=0
for i in stocks:
    
    df=get_historical_data(i)
    df=df[df.index>start]
    close=df.Close
    #arr.append(close)
    daf[a]=close
    a=a+1
daf.columns=stocks
#print(daf)
corrMatrix = daf.corr()
print (corrMatrix)
#fdf=pd.DataFrame(data=arr[0])
#print(fdf)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#            HYG       IEF       LQD       UUP       TLT      MSOS
# HYG   1.000000 -0.266377 -0.048952 -0.765084 -0.367013  0.837338
# IEF  -0.266377  1.000000  0.918112  0.405272  0.974937  0.668746
# LQD  -0.048952  0.918112  1.000000  0.306358  0.904002  0.752346
# UUP  -0.765084  0.405272  0.306358  1.000000  0.517495 -0.870066
# TLT  -0.367013  0.974937  0.904002  0.517495  1.000000  0.552396
# MSOS  0.837338  0.668746  0.752346 -0.870066  0.552396  1.000000
